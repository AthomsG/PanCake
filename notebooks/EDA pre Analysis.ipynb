# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
taxon_of_interest = ['infantis', 'bacteroides']
taxon_of_interest = taxon_of_interest[0]

# %%
# Data after pre-processing!
path_to_genes   = f'../outputs/{taxon_of_interest}-genes/process-data/genes_filtered.parquet' # coverage values
path_to_species = f'../outputs/{taxon_of_interest}-genes/process-data/species_filtered.parquet'

df_genes   = pd.read_parquet(path_to_genes)
df_species = pd.read_parquet(path_to_species)

df_genes_presence   = df_genes > 0
df_species_presence = df_species > 0

# %% [markdown]
# # Coverage Distributions (per gene)

# %%
# Out:
#              GCA_000730125.1#JNWB01000001.1#10#10857#12170#1#00  \
# ERR10299543                                          12.964503
# SRR27430636                                           0.907285
# ERR13652956                                          13.820000
# ERR10299212                                           2.860927
# SRR18173759                                        1576.610469
# ...                                                        ...
# SRR15436067                                           0.000000
# ERR11442108                                           0.000000
# SRR14672164                                           0.000000
# ERR2227633                                            0.000000
# ERR2227637                                            0.000000
#
#              GCA_000730125.1#JNWB01000001.1#2#942#2228#1#00  \
# ERR10299543                                       24.216330
# SRR27430636                                       12.125828
# ...

# %% [markdown]
# # Sparsity
